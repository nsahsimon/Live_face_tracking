# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Enter the project directory
# %cd /content/drive/MyDrive/deep_learning_projects/Live_face_tracking
# Out:
# /content/drive/MyDrive/deep_learning_projects/Live_face_tracking

# %%
# paste and run git config lines here
# !git config --global user.name "nsahsimon"
# !git config --global user.email "<email>"
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# !git push origin main
# Out:
# [master (root-commit) fae4a04] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 live_face_detection.ipynb
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.16 KiB | 297.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/nsahsimon/Live_face_tracking
#  * [new branch]      main -> main

# %%
# paste and run git config lines here
# !git config --global user.name "<username>"
# !git config --global user.email "<email>"
# !git config --global user.password "<password>"
